# %% [markdown]
# # Importing & Installing libraries

# %%
# !pip install refinitiv-data
# Out:
# Collecting refinitiv-data
#   Downloading refinitiv_data-1.6.1-py3-none-any.whl (900 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 900.7/900.7 kB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: appdirs~=1.4.4 in /usr/local/lib/python3.10/dist-packages (from refinitiv-data) (1.4.4)
# Collecting pyee<=11.1.0,>=9.0.4 (from refinitiv-data)
#   Downloading pyee-11.1.0-py3-none-any.whl (15 kB)
# Collecting httpx<0.27.0,>=0.18.0 (from refinitiv-data)
#   Downloading httpx-0.26.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 7.0 MB/s eta 0:00:00
# Collecting httpcore<1.1.0 (from refinitiv-data)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.8 MB/s eta 0:00:00
# Collecting PyMySQL>=1.0.2 (from refinitiv-data)
#   Downloading PyMySQL-1.1.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy~=1.11 in /usr/local/lib/python3.10/dist-packages (from refinitiv-data) (1.25.2)
# Requirement already satisfied: pandas<3.0.0,>=1.3.5 in /usr/local/lib/python3.10/dist-packages (from refinitiv-data) (2.0.3)
# Requirement already satisfied: python-dateutil<3.0.0 in /usr/local/lib/python3.10/dist-packages (from refinitiv-data) (2.8.2)
# Requirement already satisfied: requests~=2.28 in /usr/local/lib/python3.10/dist-packages (from refinitiv-data) (2.31.0)
# Requirement already satisfied: scipy<1.13.0 in /usr/local/lib/python3.10/dist-packages (from refinitiv-data) (1.11.4)
# Requirement already satisfied: tenacity~=8.0 in /usr/local/lib/python3.10/dist-packages (from refinitiv-data) (8.3.0)
# Collecting watchdog<3.0.0,>=0.10.2 (from refinitiv-data)
#   Downloading watchdog-2.3.1-py3-none-manylinux2014_x86_64.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: websocket-client!=1.5.0,!=1.5.2,~=1.5 in /usr/local/lib/python3.10/dist-packages (from refinitiv-data) (1.8.0)
# Collecting pyhumps<4.0.0,>=3.0.2 (from refinitiv-data)
#   Downloading pyhumps-3.8.0-py3-none-any.whl (6.1 kB)
# Requirement already satisfied: jinja2<4.0.0,>=3.0.3 in /usr/local/lib/python3.10/dist-packages (from refinitiv-data) (3.1.4)
# Collecting simplejson~=3.15 (from refinitiv-data)
#   Downloading simplejson-3.19.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpcore<1.1.0->refinitiv-data) (2024.2.2)
# Collecting h11<0.15,>=0.13 (from httpcore<1.1.0->refinitiv-data)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<0.27.0,>=0.18.0->refinitiv-data) (3.7.1)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx<0.27.0,>=0.18.0->refinitiv-data) (3.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<0.27.0,>=0.18.0->refinitiv-data) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2<4.0.0,>=3.0.3->refinitiv-data) (2.1.5)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=1.3.5->refinitiv-data) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=1.3.5->refinitiv-data) (2024.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pyee<=11.1.0,>=9.0.4->refinitiv-data) (4.11.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0->refinitiv-data) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests~=2.28->refinitiv-data) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests~=2.28->refinitiv-data) (2.0.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<0.27.0,>=0.18.0->refinitiv-data) (1.2.1)
# Installing collected packages: pyhumps, watchdog, simplejson, PyMySQL, pyee, h11, httpcore, httpx, refinitiv-data
# Successfully installed PyMySQL-1.1.0 h11-0.14.0 httpcore-1.0.5 httpx-0.26.0 pyee-11.1.0 pyhumps-3.8.0 refinitiv-data-1.6.1 simplejson-3.19.2 watchdog-2.3.1

# %%
# !pip install numpy-financial
# Out:
# Collecting numpy-financial
#   Downloading numpy_financial-1.0.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.10/dist-packages (from numpy-financial) (1.25.2)
# Installing collected packages: numpy-financial
# Successfully installed numpy-financial-1.0.0

# %%
import refinitiv.data as rd
from refinitiv.data.content import pricing
from refinitiv.data.content import symbol_conversion
from refinitiv.data.discovery import Peers
import pandas as pd
import numpy as np
import numpy_financial as npf
import matplotlib.pyplot as plt
from IPython.display import display
from scipy import stats

# %% [markdown]
# # Stablishing the LSEG session

# %%
rd.open_session(name='platform.rdp',
                config_name="./refinitiv-data.config.json")
# Out:
# /usr/local/lib/python3.10/dist-packages/refinitiv/data/_access_layer/session.py:71:FutureWarning:
# You open a platform session using the default value of the signon_control parameter (signon_control=True).
# In future library version v2.0, this default will be changed to False.
# If you want to keep the same behavior as today, you will need to set the signon_control parameter to True either in the library configuration file
# ({'sessions':{'platform':{'your_session_name':{'signon_control':true}}}}) or in your code where you create the Platform Session.
# These alternative options are already supported in the current version of the library.
# <refinitiv.data.session.Definition object at 0x7db3f1d38b20 {name='rdp'}>

# %% [markdown]
# # getting data for APA

# %%
universe = ['APA.OQ']
fields = ['TR.TickerSymbol','TR.CommonName','TR.RecLabel()','TR.PriceClose','TR.CompanyMarketCap.Currency',
          'TR.F.DebtTot', 'TR.WACC','TR.F.ComShrOutsTot','TR.F.CashCashEquiv',
          'TR.FCFMean(Period=FY0)', 'TR.FCFMean(Period=FY1)', 'TR.FCFMean(Period=FY2)','TR.FCFMean(Period=FY3)', 'TR.FCFMean(Period=FY4)',
          'TR.EVtoFCFSmartEst(Period=FY1)']

# %%
df = rd.get_data(universe = universe,fields=fields)
df.columns = ['RIC','Ticker','Name','REC','Price','CURR','TotalDebt','WAAC','Shares','Cash','F0','F1','F2','F3','F4','ExitM']

# %%
df
# Out:
#       RIC Ticker           Name   REC  Price CURR   TotalDebt       WAAC  \
# 0  APA.OQ    APA  APA Corp (US)  HOLD  30.51  USD  5188000000  10.783026
#
#       Shares      Cash          F0          F1          F2          F3  \
# 0  303575901  87000000  1297736890  1429000000  1585428570  1069000000
#
#            F4      ExitM
# 0  1071000000  12.883214

# %% [markdown]
# # Getting the data for the DCF

# %%
universe = ['APA.OQ','FANG.OQ','DVN.N','MRO.N','COP.N','EOG.N']

# %%
fields = ['TR.TickerSymbol','TR.CommonName','TR.RecLabel()','TR.PriceClose','TR.CompanyMarketCap.Currency',
          'TR.F.DebtTot', 'TR.WACC','TR.F.ComShrOutsTot','TR.F.CashCashEquiv',
          'TR.FCFMean(Period=FY0)', 'TR.FCFMean(Period=FY1)', 'TR.FCFMean(Period=FY2)','TR.FCFMean(Period=FY3)', 'TR.FCFMean(Period=FY4)',
          'TR.EVtoFCFSmartEst(Period=FY1)']

# %%
df = rd.get_data(universe = universe,fields=fields)
df.columns = ['RIC','Ticker','Name','REC','Price','CURR','TotalDebt','WAAC','Shares','Cash','F0','F1','F2','F3','F4','ExitM']

# %%
df
# Out:
#        RIC Ticker                    Name   REC   Price    TotalDebt  \
# 0   APA.OQ    APA           APA Corp (US)  HOLD   30.51   5188000000
# 1  FANG.OQ   FANG  Diamondback Energy Inc   BUY  194.59   6641000000
# 2    DVN.N    DVN       Devon Energy Corp   BUY   49.24   6462000000
# 3    MRO.N    MRO       Marathon Oil Corp   BUY   26.13   5447000000
# 4    COP.N    COP          Conocophillips   BUY  119.83  18937000000
# 5    EOG.N    EOG       EOG Resources Inc   BUY  127.92   3799000000
#
#         WAAC      Shares        Cash           F0           F1           F2  \
# 0  10.783026   303575901    87000000   1297736890   1429000000   1585428570
# 1   9.067109   178723871   582000000   2782948250   3137340860   4924120930
# 2   9.633734   635700000   853000000   2748711110   3189314620   3283869230
# 3   9.247658   577000000   155000000   2162070550   2067260100   2065418300
# 4   7.519899  1178101555  5635000000  10321918180  10014258460  11203273330
# 5   8.065599   580860368  5278000000   4944442400   5591600000   6004000000
#
#             F3          F4      ExitM
# 0   1069000000  1071000000  12.883214
# 1   4829005500  5069300670  12.878337
# 2   3034978750  2647000000  11.343832
# 3   1916840670  1778665000   9.403575
# 4  11867745000  9598750000  15.908995
# 5   5642680000  4734500000  12.556369

# %%
def DCF(universe,TGR = 2,drop_na = False,reduced_return = True):

  def calculate_npv(row):
    cash_flows = row[['F0', 'F1', 'F2', 'F3', 'F4']].values
    rate = row['WAAC']/100
    return npf.npv(rate, cash_flows)

  def get_terminal_perpetuity_value(row,TGR):

    last_free_cash_flow_firm = row['F4']
    WAAC = row['WAAC']/100
    TGR = TGR/100

    if WAAC - TGR > TGR:
      perpetuity = last_free_cash_flow_firm*(1+TGR)/(WAAC-TGR)
      perpetuity = -1*npf.pv(rate = WAAC,nper = 5,pmt =0,fv = perpetuity)
    else:
      perpetuity = last_free_cash_flow_firm*(1+TGR)/(TGR)
      perpetuity = -1*npf.pv(rate = WAAC,nper = 5,pmt =0,fv = perpetuity)
    return perpetuity

  def get_terminal_multiple(row):
    WAAC = row['WAAC']/100
    last_cash = row['F4']
    exit_m = row['ExitM']
    TV = last_cash*exit_m

    TV = -1*npf.pv(rate = WAAC,nper = 5,pmt =0,fv = TV)

    return TV


  fields = ['TR.TickerSymbol','TR.CommonName','TR.RecLabel()','TR.PriceClose','TR.CompanyMarketCap.Currency',
          'TR.F.DebtTot', 'TR.WACC','TR.F.ComShrOutsTot','TR.F.CashCashEquiv',
          'TR.FCFMean(Period=FY0)', 'TR.FCFMean(Period=FY1)', 'TR.FCFMean(Period=FY2)','TR.FCFMean(Period=FY3)', 'TR.FCFMean(Period=FY4)',
          'TR.EVtoFCFSmartEst(Period=FY1)']

  data = rd.get_data(universe = universe,fields=fields)
  data.columns =  ['RIC','Ticker','Name','REC','Price','CURR','TotalDebt','WAAC','Shares','Cash','F0','F1','F2','F3','F4','ExitM']

  data[['F0', 'F1', 'F2', 'F3', 'F4']] = data[['F0', 'F1', 'F2', 'F3', 'F4']].ffill(axis=1)

  if drop_na:
    data = data.dropna()
  else:
    data[['F0', 'F1', 'F2', 'F3', 'F4']] = data[['F0', 'F1', 'F2', 'F3', 'F4']].fillna(0)

    data['WAAC'] = data['WAAC'].fillna(5)

    data['TotalDebt'] = data['TotalDebt'].fillna(0)

  data['NPV'] = data.apply(calculate_npv, axis=1)


  data['TV_gordon'] = data.apply(lambda row: get_terminal_perpetuity_value(row, TGR = TGR), axis=1)

  data['TV_mult'] = data.apply(get_terminal_multiple, axis=1)

  data['EV_gordon'] = data['NPV'] + data['TV_gordon'] - data['TotalDebt'] + data['Cash']

  data['EV_mult'] = data['NPV'] + data['TV_mult'] - data['TotalDebt'] + data['Cash']

  data['DCF_Price_gordon'] = data['EV_gordon']/data['Shares']

  data['DCF_Price_mult'] = data['EV_mult']/data['Shares']

  data['WAAC'] = data['WAAC']/100

  data['DCF_Price'] = (data['DCF_Price_gordon'] + data['DCF_Price_mult'])/2

  data['delta'] = data['DCF_Price'] - data['Price']

  data = data.sort_values(by=['delta'],ascending =[False]).reset_index(drop=True)

  if reduced_return:
    data = data[['Name','RIC','Ticker','CURR','REC','WAAC','Price','DCF_Price_gordon','DCF_Price_mult','DCF_Price','delta']]

    return data

  if not reduced_return:

    return data

# %%
DCF(['APA.OQ'],TGR = 3,drop_na = False)
# Out:
#             Name     RIC Ticker CURR   REC     WAAC  Price  DCF_Price_gordon  \
# 0  APA Corp (US)  APA.OQ    APA  USD  HOLD  0.10783  30.51          28.88815
#
#    DCF_Price_mult  DCF_Price     delta
# 0       28.146657  28.517404 -1.992596

# %%
universe = ['APA.OQ','FANG.OQ','DVN.N','MRO.N','COP.N','EOG.N']

# %%
oil = DCF(universe,TGR = 3,drop_na = False)

# %%
# def return_styled_df(df,save_to_excel=False,file_name='df_score'):

#   headers = {
#     "selector": "th:not(.index_name)",
#     "props": "background-color: #800000; color: white; text-align: center"}
#   name_cell = {'selector': '',
#               'props': "background-color: #281E5D; color: white; text-align: center"}
#   properties = {"border": "1px solid black", "width": "65px", "text-align": "center"}

#   df = df.style.format({
#       "WAAC": "{:.3f}",
#       "Price":"{:.2f} $",
#       "DCF_Price":"{:.2f} $",
#       "delta":"{:.2f} $",}).\
#       background_gradient(subset=["delta"],cmap="RdYlGn").\
#       set_table_styles([headers]).set_properties(**properties).\
#       set_table_styles({'Name': [name_cell]}, overwrite=False)

#   if save_to_excel:
#     filename= f"{file_name}.xlsx"
#     df.to_excel(filename)

#   return df

# %%
def color_negative_red(val):
    """
    Takes a scalar and returns a string with the css property `'color: red'` for negative
    values, `'color: green'` for positive values, and `'color: black'` for zero values.
    """
    color = 'green' if val > 0 else 'red' if val < 0 else 'yellow'
    return f'background-color: {color}'

def color_gradient(val):
    """
    Return a gradient color based on the value.
    Positive values get shades of green, and negative values get shades of red.
    """
    if val > 0:
        return f'background-color: rgba(0, 255, 0, {min(val/10, 1)})'  # green shades
    elif val < 0:
        return f'background-color: rgba(255, 0, 0, {min(abs(val)/10, 1)})'  # red shades
    else:
        return 'background-color: yellow'

def return_styled_df(df, save_to_excel=False, file_name='df_score'):
    headers = {
        "selector": "th:not(.index_name)",
        "props": "background-color: #800000; color: white; text-align: center"}
    name_cell = {'selector': '',
                'props': "background-color: #281E5D; color: white; text-align: center"}
    properties = {"border": "1px solid black", "width": "65px", "text-align": "center"}

    df = df.style.format({
        "WAAC": "{:.3f}",
        "Price": "{:.2f} $",
        "DCF_Price": "{:.2f} $",
        "delta": "{:.2f} $"
    }).applymap(color_gradient, subset=["delta"]).set_table_styles([headers]).set_properties(**properties).set_table_styles({'Name': [name_cell]}, overwrite=False)

    if save_to_excel:
        filename = f"{file_name}.xlsx"
        df.to_excel(filename, engine='openpyxl', index=False)

    return df

# %%
return_styled_df(oil)
# Out:
# <style type="text/css">
# #T_a7788 th:not(.index_name) {
#   background-color: #800000;
#   color: white;
#   text-align: center;
# }
# #T_a7788 .col0 {
#   background-color: #281E5D;
#   color: white;
#   text-align: center;
# }
# #T_a7788_row0_col0, #T_a7788_row0_col1, #T_a7788_row0_col2, #T_a7788_row0_col3, #T_a7788_row0_col4, #T_a7788_row0_col5, #T_a7788_row0_col6, #T_a7788_row0_col7, #T_a7788_row0_col8, #T_a7788_row0_col9, #T_a7788_row1_col0, #T_a7788_row1_col1, #T_a7788_row1_col2, #T_a7788_row1_col3, #T_a7788_row1_col4, #T_a7788_row1_col5, #T_a7788_row1_col6, #T_a7788_row1_col7, #T_a7788_row1_col8, #T_a7788_row1_col9, #T_a7788_row2_col0, #T_a7788_row2_col1, #T_a7788_row2_col2, #T_a7788_row2_col3, #T_a7788_row2_col4, #T_a7788_row2_col5, #T_a7788_row2_col6, #T_a7788_row2_col7, #T_a7788_row2_col8, #T_a7788_row2_col9, #T_a7788_row3_col0, #T_a7788_row3_col1, #T_a7788_row3_col2, #T_a7788_row3_col3, #T_a7788_row3_col4, #T_a7788_row3_col5, #T_a7788_row3_col6, #T_a7788_row3_col7, #T_a7788_row3_col8, #T_a7788_row3_col9, #T_a7788_row4_col0, #T_a7788_row4_col1, #T_a7788_row4_col2, #T_a7788_row4_col3, #T_a7788_row4_col4, #T_a7788_row4_col5, #T_a7788_row4_col6, #T_a7788_row4_col7, #T_a7788_row4_col8, #T_a7788_row4_col9, #T_a7788_row5_col0, #T_a7788_row5_col1, #T_a7788_row5_col2, #T_a7788_row5_col3, #T_a7788_row5_col4, #T_a7788_row5_col5, #T_a7788_row5_col6, #T_a7788_row5_col7, #T_a7788_row5_col8, #T_a7788_row5_col9 {
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
# }
# #T_a7788_row0_col10, #T_a7788_row1_col10 {
#   background-color: rgba(0, 255, 0, 1);
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
# }
# #T_a7788_row2_col10 {
#   background-color: rgba(0, 255, 0, 0.5511153471592237);
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
# }
# #T_a7788_row3_col10 {
#   background-color: rgba(0, 255, 0, 0.5226213630759627);
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
# }
# #T_a7788_row4_col10 {
#   background-color: rgba(255, 0, 0, 0.20128224845424433);
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
# }
# #T_a7788_row5_col10 {
#   background-color: rgba(255, 0, 0, 0.30461601107605885);
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
# }
# </style>
# <table id="T_a7788" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a7788_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_a7788_level0_col1" class="col_heading level0 col1" >RIC</th>
#       <th id="T_a7788_level0_col2" class="col_heading level0 col2" >Ticker</th>
#       <th id="T_a7788_level0_col3" class="col_heading level0 col3" >CURR</th>
#       <th id="T_a7788_level0_col4" class="col_heading level0 col4" >REC</th>
#       <th id="T_a7788_level0_col5" class="col_heading level0 col5" >WAAC</th>
#       <th id="T_a7788_level0_col6" class="col_heading level0 col6" >Price</th>
#       <th id="T_a7788_level0_col7" class="col_heading level0 col7" >DCF_Price_gordon</th>
#       <th id="T_a7788_level0_col8" class="col_heading level0 col8" >DCF_Price_mult</th>
#       <th id="T_a7788_level0_col9" class="col_heading level0 col9" >DCF_Price</th>
#       <th id="T_a7788_level0_col10" class="col_heading level0 col10" >delta</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7788_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a7788_row0_col0" class="data row0 col0" >Diamondback Energy Inc</td>
#       <td id="T_a7788_row0_col1" class="data row0 col1" >FANG.OQ</td>
#       <td id="T_a7788_row0_col2" class="data row0 col2" >FANG</td>
#       <td id="T_a7788_row0_col3" class="data row0 col3" >USD</td>
#       <td id="T_a7788_row0_col4" class="data row0 col4" >BUY</td>
#       <td id="T_a7788_row0_col5" class="data row0 col5" >0.091</td>
#       <td id="T_a7788_row0_col6" class="data row0 col6" >194.59 $</td>
#       <td id="T_a7788_row0_col7" class="data row0 col7" >373.590910</td>
#       <td id="T_a7788_row0_col8" class="data row0 col8" >298.434281</td>
#       <td id="T_a7788_row0_col9" class="data row0 col9" >336.01 $</td>
#       <td id="T_a7788_row0_col10" class="data row0 col10" >141.42 $</td>
#     </tr>
#     <tr>
#       <th id="T_a7788_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a7788_row1_col0" class="data row1 col0" >Conocophillips</td>
#       <td id="T_a7788_row1_col1" class="data row1 col1" >COP.N</td>
#       <td id="T_a7788_row1_col2" class="data row1 col2" >COP</td>
#       <td id="T_a7788_row1_col3" class="data row1 col3" >USD</td>
#       <td id="T_a7788_row1_col4" class="data row1 col4" >BUY</td>
#       <td id="T_a7788_row1_col5" class="data row1 col5" >0.075</td>
#       <td id="T_a7788_row1_col6" class="data row1 col6" >119.83 $</td>
#       <td id="T_a7788_row1_col7" class="data row1 col7" >156.978967</td>
#       <td id="T_a7788_row1_col8" class="data row1 col8" >118.003256</td>
#       <td id="T_a7788_row1_col9" class="data row1 col9" >137.49 $</td>
#       <td id="T_a7788_row1_col10" class="data row1 col10" >17.66 $</td>
#     </tr>
#     <tr>
#       <th id="T_a7788_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a7788_row2_col0" class="data row2 col0" >EOG Resources Inc</td>
#       <td id="T_a7788_row2_col1" class="data row2 col1" >EOG.N</td>
#       <td id="T_a7788_row2_col2" class="data row2 col2" >EOG</td>
#       <td id="T_a7788_row2_col3" class="data row2 col3" >USD</td>
#       <td id="T_a7788_row2_col4" class="data row2 col4" >BUY</td>
#       <td id="T_a7788_row2_col5" class="data row2 col5" >0.081</td>
#       <td id="T_a7788_row2_col6" class="data row2 col6" >127.92 $</td>
#       <td id="T_a7788_row2_col7" class="data row2 col7" >154.929714</td>
#       <td id="T_a7788_row2_col8" class="data row2 col8" >111.932593</td>
#       <td id="T_a7788_row2_col9" class="data row2 col9" >133.43 $</td>
#       <td id="T_a7788_row2_col10" class="data row2 col10" >5.51 $</td>
#     </tr>
#     <tr>
#       <th id="T_a7788_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a7788_row3_col0" class="data row3 col0" >Marathon Oil Corp</td>
#       <td id="T_a7788_row3_col1" class="data row3 col1" >MRO.N</td>
#       <td id="T_a7788_row3_col2" class="data row3 col2" >MRO</td>
#       <td id="T_a7788_row3_col3" class="data row3 col3" >USD</td>
#       <td id="T_a7788_row3_col4" class="data row3 col4" >BUY</td>
#       <td id="T_a7788_row3_col5" class="data row3 col5" >0.092</td>
#       <td id="T_a7788_row3_col6" class="data row3 col6" >26.13 $</td>
#       <td id="T_a7788_row3_col7" class="data row3 col7" >38.422560</td>
#       <td id="T_a7788_row3_col8" class="data row3 col8" >24.289867</td>
#       <td id="T_a7788_row3_col9" class="data row3 col9" >31.36 $</td>
#       <td id="T_a7788_row3_col10" class="data row3 col10" >5.23 $</td>
#     </tr>
#     <tr>
#       <th id="T_a7788_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a7788_row4_col0" class="data row4 col0" >APA Corp (US)</td>
#       <td id="T_a7788_row4_col1" class="data row4 col1" >APA.OQ</td>
#       <td id="T_a7788_row4_col2" class="data row4 col2" >APA</td>
#       <td id="T_a7788_row4_col3" class="data row4 col3" >USD</td>
#       <td id="T_a7788_row4_col4" class="data row4 col4" >HOLD</td>
#       <td id="T_a7788_row4_col5" class="data row4 col5" >0.108</td>
#       <td id="T_a7788_row4_col6" class="data row4 col6" >30.51 $</td>
#       <td id="T_a7788_row4_col7" class="data row4 col7" >28.856854</td>
#       <td id="T_a7788_row4_col8" class="data row4 col8" >28.137501</td>
#       <td id="T_a7788_row4_col9" class="data row4 col9" >28.50 $</td>
#       <td id="T_a7788_row4_col10" class="data row4 col10" >-2.01 $</td>
#     </tr>
#     <tr>
#       <th id="T_a7788_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a7788_row5_col0" class="data row5 col0" >Devon Energy Corp</td>
#       <td id="T_a7788_row5_col1" class="data row5 col1" >DVN.N</td>
#       <td id="T_a7788_row5_col2" class="data row5 col2" >DVN</td>
#       <td id="T_a7788_row5_col3" class="data row5 col3" >USD</td>
#       <td id="T_a7788_row5_col4" class="data row5 col4" >BUY</t

# %%
DCF(['AAPL.O','GOOG.O','MSFT.O'],TGR = 3,drop_na=False)
# Out:
#              Name     RIC Ticker CURR  REC      WAAC   Price  \
# 0    Alphabet Inc  GOOG.O   GOOG  USD  BUY  0.073387  175.43
# 1  Microsoft Corp  MSFT.O   MSFT  USD  BUY  0.069446  420.99
# 2       Apple Inc  AAPL.O   AAPL  USD  BUY  0.079136  189.84
#
#    DCF_Price_gordon  DCF_Price_mult   DCF_Price      delta
# 0        208.798075      224.067693  216.432884  41.002884
# 1        313.202613      507.799301  410.500957 -10.489043
# 2        143.716629      180.168913  161.942771 -27.897229

# %% [markdown]
# # Running the DCF for the entire S&P500

# %%
sp500 = pricing.chain.Definition(name="0#.SPX").get_stream()
sp500.open()
sp500_RICS = sp500.constituents
sp500.close()
# Out:
# <OpenState.Closed: 'Closed'>

# %%
SP500_DCF = DCF(sp500_RICS,TGR = 3,drop_na=True)

# %%
return_styled_df(SP500_DCF.head(10))
# Out:
# <style type="text/css">
# #T_5641b th:not(.index_name) {
#   background-color: #800000;
#   color: white;
#   text-align: center;
# }
# #T_5641b .col0 {
#   background-color: #281E5D;
#   color: white;
#   text-align: center;
# }
# #T_5641b_row0_col0, #T_5641b_row0_col1, #T_5641b_row0_col2, #T_5641b_row0_col3, #T_5641b_row0_col4, #T_5641b_row0_col5, #T_5641b_row0_col6, #T_5641b_row0_col7, #T_5641b_row0_col8, #T_5641b_row0_col9, #T_5641b_row1_col0, #T_5641b_row1_col1, #T_5641b_row1_col2, #T_5641b_row1_col3, #T_5641b_row1_col4, #T_5641b_row1_col5, #T_5641b_row1_col6, #T_5641b_row1_col7, #T_5641b_row1_col8, #T_5641b_row1_col9, #T_5641b_row2_col0, #T_5641b_row2_col1, #T_5641b_row2_col2, #T_5641b_row2_col3, #T_5641b_row2_col4, #T_5641b_row2_col5, #T_5641b_row2_col6, #T_5641b_row2_col7, #T_5641b_row2_col8, #T_5641b_row2_col9, #T_5641b_row3_col0, #T_5641b_row3_col1, #T_5641b_row3_col2, #T_5641b_row3_col3, #T_5641b_row3_col4, #T_5641b_row3_col5, #T_5641b_row3_col6, #T_5641b_row3_col7, #T_5641b_row3_col8, #T_5641b_row3_col9, #T_5641b_row4_col0, #T_5641b_row4_col1, #T_5641b_row4_col2, #T_5641b_row4_col3, #T_5641b_row4_col4, #T_5641b_row4_col5, #T_5641b_row4_col6, #T_5641b_row4_col7, #T_5641b_row4_col8, #T_5641b_row4_col9, #T_5641b_row5_col0, #T_5641b_row5_col1, #T_5641b_row5_col2, #T_5641b_row5_col3, #T_5641b_row5_col4, #T_5641b_row5_col5, #T_5641b_row5_col6, #T_5641b_row5_col7, #T_5641b_row5_col8, #T_5641b_row5_col9, #T_5641b_row6_col0, #T_5641b_row6_col1, #T_5641b_row6_col2, #T_5641b_row6_col3, #T_5641b_row6_col4, #T_5641b_row6_col5, #T_5641b_row6_col6, #T_5641b_row6_col7, #T_5641b_row6_col8, #T_5641b_row6_col9, #T_5641b_row7_col0, #T_5641b_row7_col1, #T_5641b_row7_col2, #T_5641b_row7_col3, #T_5641b_row7_col4, #T_5641b_row7_col5, #T_5641b_row7_col6, #T_5641b_row7_col7, #T_5641b_row7_col8, #T_5641b_row7_col9, #T_5641b_row8_col0, #T_5641b_row8_col1, #T_5641b_row8_col2, #T_5641b_row8_col3, #T_5641b_row8_col4, #T_5641b_row8_col5, #T_5641b_row8_col6, #T_5641b_row8_col7, #T_5641b_row8_col8, #T_5641b_row8_col9, #T_5641b_row9_col0, #T_5641b_row9_col1, #T_5641b_row9_col2, #T_5641b_row9_col3, #T_5641b_row9_col4, #T_5641b_row9_col5, #T_5641b_row9_col6, #T_5641b_row9_col7, #T_5641b_row9_col8, #T_5641b_row9_col9 {
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
# }
# #T_5641b_row0_col10, #T_5641b_row1_col10, #T_5641b_row2_col10, #T_5641b_row3_col10, #T_5641b_row4_col10, #T_5641b_row5_col10, #T_5641b_row6_col10, #T_5641b_row7_col10, #T_5641b_row8_col10, #T_5641b_row9_col10 {
#   background-color: rgba(0, 255, 0, 1);
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
# }
# </style>
# <table id="T_5641b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5641b_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_5641b_level0_col1" class="col_heading level0 col1" >RIC</th>
#       <th id="T_5641b_level0_col2" class="col_heading level0 col2" >Ticker</th>
#       <th id="T_5641b_level0_col3" class="col_heading level0 col3" >CURR</th>
#       <th id="T_5641b_level0_col4" class="col_heading level0 col4" >REC</th>
#       <th id="T_5641b_level0_col5" class="col_heading level0 col5" >WAAC</th>
#       <th id="T_5641b_level0_col6" class="col_heading level0 col6" >Price</th>
#       <th id="T_5641b_level0_col7" class="col_heading level0 col7" >DCF_Price_gordon</th>
#       <th id="T_5641b_level0_col8" class="col_heading level0 col8" >DCF_Price_mult</th>
#       <th id="T_5641b_level0_col9" class="col_heading level0 col9" >DCF_Price</th>
#       <th id="T_5641b_level0_col10" class="col_heading level0 col10" >delta</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5641b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5641b_row0_col0" class="data row0 col0" >NVR Inc</td>
#       <td id="T_5641b_row0_col1" class="data row0 col1" >NVR.N</td>
#       <td id="T_5641b_row0_col2" class="data row0 col2" >NVR</td>
#       <td id="T_5641b_row0_col3" class="data row0 col3" >USD</td>
#       <td id="T_5641b_row0_col4" class="data row0 col4" >BUY</td>
#       <td id="T_5641b_row0_col5" class="data row0 col5" >0.077</td>
#       <td id="T_5641b_row0_col6" class="data row0 col6" >7702.96 $</td>
#       <td id="T_5641b_row0_col7" class="data row0 col7" >9976.054005</td>
#       <td id="T_5641b_row0_col8" class="data row0 col8" >7619.308248</td>
#       <td id="T_5641b_row0_col9" class="data row0 col9" >8797.68 $</td>
#       <td id="T_5641b_row0_col10" class="data row0 col10" >1094.72 $</td>
#     </tr>
#     <tr>
#       <th id="T_5641b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5641b_row1_col0" class="data row1 col0" >Autozone Inc</td>
#       <td id="T_5641b_row1_col1" class="data row1 col1" >AZO.N</td>
#       <td id="T_5641b_row1_col2" class="data row1 col2" >AZO</td>
#       <td id="T_5641b_row1_col3" class="data row1 col3" >USD</td>
#       <td id="T_5641b_row1_col4" class="data row1 col4" >BUY</td>
#       <td id="T_5641b_row1_col5" class="data row1 col5" >0.062</td>
#       <td id="T_5641b_row1_col6" class="data row1 col6" >2900.99 $</td>
#       <td id="T_5641b_row1_col7" class="data row1 col7" >4630.220901</td>
#       <td id="T_5641b_row1_col8" class="data row1 col8" >2987.877587</td>
#       <td id="T_5641b_row1_col9" class="data row1 col9" >3809.05 $</td>
#       <td id="T_5641b_row1_col10" class="data row1 col10" >908.06 $</td>
#     </tr>
#     <tr>
#       <th id="T_5641b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5641b_row2_col0" class="data row2 col0" >Elevance Health Inc</td>
#       <td id="T_5641b_row2_col1" class="data row2 col1" >ELV.N</td>
#       <td id="T_5641b_row2_col2" class="data row2 col2" >ELV</td>
#       <td id="T_5641b_row2_col3" class="data row2 col3" >USD</td>
#       <td id="T_5641b_row2_col4" class="data row2 col4" >BUY</td>
#       <td id="T_5641b_row2_col5" class="data row2 col5" >0.059</td>
#       <td id="T_5641b_row2_col6" class="data row2 col6" >543.89 $</td>
#       <td id="T_5641b_row2_col7" class="data row2 col7" >1652.575882</td>
#       <td id="T_5641b_row2_col8" class="data row2 col8" >981.404624</td>
#       <td id="T_5641b_row2_col9" class="data row2 col9" >1316.99 $</td>
#       <td id="T_5641b_row2_col10" class="data row2 col10" >773.10 $</td>
#     </tr>
#     <tr>
#       <th id="T_5641b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5641b_row3_col0" class="data row3 col0" >Equinix Inc</td>
#       <td id="T_5641b_row3_col1" class="data row3 col1" >EQIX.OQ</td>
#       <td id="T_5641b_row3_col2" class="data row3 col2" >EQIX</td>
#       <td id="T_5641b_row3_col3" class="data row3 col3" >USD</td>
#       <td id="T_5641b_row3_col4" class="data row3 col4" >BUY</td>
#       <td id="T_5641b_row3_col5" class="data row3 col5" >0.061</td>
#       <td id="T_5641b_row3_col6" class="data row3 col6" >799.50 $</td>
#       <td id="T_5641b_row3_col7" class="data row3 col7" >525.369366</td>
#       <td id="T_5641b_row3_col8" class="data row3 col8" >2587.313738</td>
#       <td id="T_5641b_row3_col9" class="data row3 col9" >1556.34 $</td>
#       <td id="T_5641b_row3_col10" class="data row3 col10" >756.84 $</td>
#     </tr>
#     <tr>
#       <th id="T_5641b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5641b_row4_col0" class="data row4 col0" >Charter Communications Inc</td>
#       <td id="T_5641b_row4_col1" class="data row4 col1" >CHTR.OQ</td>
#       <td id="T_5641b_row4_col2" class="data row4 col2" >CHTR</td>
#       <td id="T_5641b_row4_col3" class="data row4 col3" >USD</td>
#       <td id="T_5641b_row4_col4" class="data row4 col4" >HOLD</td>
#       <td id="T_5641b_row4_col5" class="data row4 col5" >0.059</td>
#       <td id="T_5641b_row4_col6" class="data row4 col6" >277.54 $</td>
#       <td id="T_5641b_row4_col7" class="data row4 col7" >601.342285</td>
#       <td id="T_5641b_row4_col8" class="data row4 col8" >1321.844417</td>
#       <td id="T_5641b_row4_col9" class="data row4 col9" >961.59 $</td>
#       <td id="T_5641b_row4_col10" class="data row4 col10" >684.05 $</td>
#     </tr>
#     <tr>
#       <th
